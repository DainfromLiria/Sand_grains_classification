# %%
from augmentation import Augmentation
# Out:
# D:\Python\Lib\site-packages\albumentations\check_version.py:51: UserWarning: Error fetching version info <urlopen error [Errno 11002] getaddrinfo failed>
#   data = fetch_version_info()

# %%
aug = Augmentation()
aug.augment()
# Out:
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# Time taken for augment 2 images: 0.12s
